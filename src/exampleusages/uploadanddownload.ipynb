# %%
df = spark.read.csv("/Volumes/workspace/exampleusages/uploadinganddownloading/csv/sales.csv", inferSchema = True, header = True)
df.show()

# %%
display(df)

# %%
df.write.mode("overwrite").csv("/Volumes/workspace/exampleusages/uploadinganddownloading/csv/output/")

# %%
df.write.mode("overwrite").parquet("/Volumes/workspace/exampleusages/uploadinganddownloading/parquet/output_parquet/")
