# %%
dbutils.fs.mkdirs("dbfs:/Volumes/workspace/dbfs/dbfs_vol/csv")

# %%
dbutils.fs.ls("dbfs:/")

# %%
data = [
    (1, "Alice", 500),
    (2, "Bob", 1500),
    (3, "Charlie", 800),
    (4, "David", 2000)
]

columns = ["id", "name", "sales"]

df = spark.createDataFrame(data, columns)
df.show()

# %%
dbutils.fs.ls("dbfs:/Volumes/workspace/dbfs/dbfs_vol/csv")

# %%
read_dbfs = spark.read.csv("dbfs:/Volumes/workspace/dbfs/dbfs_vol/csv", inferSchema=True, header=True)
read_dbfs.show()
