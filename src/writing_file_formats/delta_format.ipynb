# %%
data = [(1, "Kashish", 22), (2, "Ankit", 24), (3, "Raj", 20), (4, "Priyanka", 18), (5, "Rahul", 21), (6, "Vaishnavi", 18), (7, "Aryan", 30), (8, "Ankush", 25), (9, "Sidra", 22), (10, "Komal", 20)]
df = spark.createDataFrame(data, ["id", "name", "age"])
df.write.format("delta")\
  .option("header", "true")\
  .mode("overwrite")\
  .save("dbfs:/Volumes/workspace/writingformats/file_formats_write/delta_file")

df.display()

# %%
data = [(11, "Priya", 20), (12, "Rajesh", 20)]
df = spark.createDataFrame(data, ["id", "name", "age"])
df.write.format("delta")\
  .mode("append")\
  .save("dbfs:/Volumes/workspace/writingformats/file_formats_write/delta_file")
