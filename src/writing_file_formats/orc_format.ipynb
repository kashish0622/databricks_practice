# %%
data = [(11, "Priya", 20), (12, "Rajesh", 20)]
df = spark.createDataFrame(data, ["id", "name", "age"])
df.write.format("orc")\
  .mode("overwrite")\
  .save("dbfs:/Volumes/workspace/writingformats/file_formats_write/orc_file")
