# %%
data = [(1, "Alice", 90), (2, "Bob", 75), (3, "Charlie", 82)]
df = spark.createDataFrame(data, ["id", "name", "score"])
df.write.mode("overwrite").json("dbfs:/Volumes/workspace/exampleusages/uploadinganddownloading/text.json")
df.show()

# %%
dbutils.fs.ls("dbfs:/Volumes/workspace/exampleusages/uploadinganddownloading")
