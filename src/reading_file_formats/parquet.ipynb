# %%
data = [(1, "Alice", 90), (2, "Bob", 75), (3, "Charlie", 82)]
df = spark.createDataFrame(data, ["id", "name", "score"])
#df.write.mode("overwrite").parquet("dbfs:/Volumes/workspace/exampleusages/uploadinganddownloading/parquet/output_parquet")
df = spark.read.parquet("dbfs:/Volumes/workspace/exampleusages/uploadinganddownloading/parquet/output_parquet")
df.show()
